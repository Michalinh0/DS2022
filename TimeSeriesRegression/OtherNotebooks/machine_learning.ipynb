# %% [markdown]
# <a href="https://colab.research.google.com/github/Michalinh0/DS2022/blob/main/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
import lightgbm as lgb
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neural_network import MLPRegressor

# %%
df = pd.read_csv("/content/drive/MyDrive/data60_2.csv")

# %%
pd.set_option("display.max_rows", 600)
df.dtypes
# Out:
# ut_ms                                        int64
# panels [J/m2]@influx                        object
# front [J/m2]@influx                         object
# back [J/m2]@influx                          object
# left [J/m2]@influx                          object
# right [J/m2]@influx                         object
# up [J/m2]@influx                            object
# down [J/m2]@influx                          object
# panels-sum1 [J/m2]@influx_sum               object
# panels-sum1-decay0.9 [J/m2]@influx_sum      object
# panels-sum1-decay0.75 [J/m2]@influx_sum     object
# panels-sum1-decay0.5 [J/m2]@influx_sum      object
# panels-sum1-decay0.25 [J/m2]@influx_sum     object
# panels-sum2 [J/m2]@influx_sum               object
# panels-sum2-decay0.9 [J/m2]@influx_sum      object
# panels-sum2-decay0.75 [J/m2]@influx_sum     object
# panels-sum2-decay0.5 [J/m2]@influx_sum      object
# panels-sum2-decay0.25 [J/m2]@influx_sum     object
# ...

# %%
xd = df.corr()

xd.columns
# Out:
# Index(['ut_ms', 'ACROSS_TRACK []@ftl', 'D1PVMC []@ftl', 'D2PLND []@ftl',
#        'D3POCM []@ftl', 'D4PNPO []@ftl', 'D5PPHB []@ftl', 'D7PLTS []@ftl',
#        'D8PLTP []@ftl', 'D9PSPO []@ftl',
#        ...
#        'bPPNE [min]@dmop_binary_grouped', 'bPPNS [min]@dmop_binary_grouped',
#        'bSCMN [min]@dmop_binary_grouped', 'bTrig [min]@dmop_binary_grouped',
#        'bUDBE [min]@dmop_binary_grouped', 'bUDBS [min]@dmop_binary_grouped',
#        'bUPBE [min]@dmop_binary_grouped', 'bUPBS [min]@dmop_binary_grouped',
#        'distance_sun_mars [au]@lt', 'solar_constant [W/m2]@lt'],
#       dtype='object', length=406)

# %%
pd.set_option("display.max_rows", 600)
xd.dtypes

# remove empty colums because correlation skips them
# Out:
# ut_ms                              float64
# ACROSS_TRACK []@ftl                float64
# D1PVMC []@ftl                      float64
# D2PLND []@ftl                      float64
# D3POCM []@ftl                      float64
# D4PNPO []@ftl                      float64
# D5PPHB []@ftl                      float64
# D7PLTS []@ftl                      float64
# D8PLTP []@ftl                      float64
# D9PSPO []@ftl                      float64
# EARTH []@ftl                       float64
# FLAGCOMMS []@ftl                   float64
# FLAGCOMMS_EARTH []@ftl             float64
# FLAGCOMMS_RADIO_SCIENCE []@ftl     float64
# FLAGCOMMS_WARMUP []@ftl            float64
# INERTIAL []@ftl                    float64
# MAINTENANCE []@ftl                 float64
# NADIR []@ftl                       float64
# NADIR_LANDER []@ftl                float64
# RADIO_SCIENCE []@ftl               float64
# SLEW []@ftl                        float64
# SPECULAR []@ftl                    float64
# ...
